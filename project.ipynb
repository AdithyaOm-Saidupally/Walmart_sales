# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ** step 1 data exploration and leading **

# %%
##important dependencies

import pandas as pd
